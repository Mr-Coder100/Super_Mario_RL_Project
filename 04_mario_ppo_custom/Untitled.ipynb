# %%
# %run env_without_gym.py
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# C:\Users\HP\miniconda3\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %%
# %run policy_without_gym.py

# %%
# %run train_agent_without_gym.py
# Out:
# Episode 1: Total Reward = -27.800000000000008
# Episode 2: Total Reward = -10.200000000000006
# Episode 3: Total Reward = -117.89999999999999
# Episode 4: Total Reward = -153.0
# Episode 5: Total Reward = -19.100000000000005
# Episode 6: Total Reward = -14.700000000000006
# Episode 7: Total Reward = 17.199999999999996
# Episode 8: Total Reward = -37.300000000000004
# Episode 9: Total Reward = -140.8
# Episode 10: Total Reward = -118.10000000000001
# Episode 11: Total Reward = 4.499999999999995
# Episode 12: Total Reward = -383.40000000000003
# Episode 13: Total Reward = -82.30000000000001
# Episode 14: Total Reward = -122.10000000000001
# Episode 15: Total Reward = -97.60000000000001
# Episode 16: Total Reward = -16.300000000000008
# Episode 17: Total Reward = -134.9
# Episode 18: Total Reward = -86.10000000000001
# Episode 19: Total Reward = 20.599999999999994
# Episode 20: Total Reward = -77.4
# Episode 21: Total Reward = -58.00000000000001
# ...

# %%
# %run evaluate_without_gym.py
# Out:
# C:\Users\HP\miniconda3\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Models loaded successfully from 'custom_actor.pth'
# --- Running Episode 1 ---
