# %%
# %run mario_env.py
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# C:\Users\HP\miniconda3\Lib\site-packages\pygame\pkgdata.py:25: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_stream, resource_exists

# %%
# %run train_agent.py
# Out:
# Using cpu device
# Training started...
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 648      |
# |    ep_rew_mean     | -98.1    |
# | time/              |          |
# |    fps             | 2366     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 749         |
# |    ep_rew_mean          | -94.9       |
# | time/                   |             |
# |    fps                  | 1366        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009958992 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# ...

# %%
# %run evaluate_agent.py
# Out:
# Model loaded from final_ppo_mario_model.zip
# Episode finished.
